# %%
# Basic Libraries
import numpy as np
import pandas as pd

# Visualization libraries
import matplotlib.pyplot as plt
import pydot
import seaborn as sns

#Evaluation library
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.model_selection import GridSearchCV

# Deep Learning libraries
import tensorflow as tf
from tensorflow.keras import layers
import keras
from keras.models import Sequential
from keras.layers.core import Dense,Activation,Dropout
from keras.datasets import mnist
from keras.utils.np_utils import to_categorical
from keras.wrappers.scikit_learn import KerasClassifier

# %%
fashion_train=pd.read_csv("fashion-mnist_train.csv")
fashion_test=pd.read_csv("fashion-mnist_test.csv")

# %%
fashion_train.shape
# Out:
# (60000, 785)

# %%
X_train_fashion = fashion_train.drop('label',axis = 1)
y_train_fashion = fashion_train['label']
X_test_fashion = fashion_test.drop('label',axis = 1)
y_test_fashion = fashion_test['label']

# %%
#Reshaping the dataset
x_train_reshape = X_train_fashion.values.reshape(-1,28,28)
x_test_reshape = X_test_fashion.values.reshape(-1,28,28)

#Names of clothing accessories in order 
col_names = ['T-shirt/top','Trouser','Pullover','Dress','Coat','Sandal','Shirt','Sneaker','Bag','Ankle boot']

#Visualizing the images
plt.figure(figsize=(10,10))
for i in range(15):
    plt.subplot(5,5,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.imshow(x_train_reshape[i], cmap='gray')
    plt.xlabel(col_names[y_train_fashion[i]])
plt.show()

# %%
y_train_fashion = to_categorical(y_train_fashion, num_classes=10)

y_test_fashion = to_categorical(y_test_fashion, num_classes=10)

# %%
#Creating base neural network
model = keras.Sequential([
    layers.Dense(128, activation='relu', input_shape=(784,)),
    layers.Dropout(0.3),
    layers.BatchNormalization(),
    layers.Dense(24, activation='relu'),
    layers.Dropout(0.3),
    layers.BatchNormalization(),
    layers.Dense(24, activation='relu'),
    layers.Dropout(0.3),
    layers.BatchNormalization(),
    layers.Dense(10,activation='softmax'),
])

#Compiling the model
model.compile(loss="categorical_crossentropy",
              optimizer="adam",
              metrics = ['accuracy'])

#Fitting the model
history=model.fit(X_train_fashion, y_train_fashion, batch_size=100, epochs=30,validation_data=(X_test_fashion, y_test_fashion))
# Out:
# Epoch 1/30
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x00000228BFD1C708> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x00000228BFD1C708> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 600/600 [==============================] - ETA: 0s - loss: 1.0887 - accuracy: 0.6355WARNING:tensorflow:AutoGraph could not transform <function Model.make_test_function.<locals>.test_function at 0x00000228BFEF4168> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_test_function.<locals>.test_function at 0x00000228BFEF4168> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 600/600 [==============================] - 9s 10ms/step - loss: 1.0887 - accuracy: 0.6355 - val_loss: 0.5840 - val_accuracy: 0.7927
# Epoch 2/30
# 600/600 [==============================] - 5s 8ms/step - loss: 0.7279 - accuracy: 0.7518 - val_loss: 0.5139 - val_accuracy: 0.8142
# Epoch 3/30
# 600/600 [==============================] - 5s 9ms/step - loss: 0.6626 - accuracy: 0.7749 - val_loss: 0.4989 - val_accuracy: 0.8221
# Epoch 4/30
# 600/600 [==============================] - 5s 8ms/step - loss: 0.6270 - accuracy: 0.7890 - val_loss: 0.4368 - val_accuracy: 0.8527
# Epoch 5/30
# 600/600 [==============================] - 5s 8ms/step - loss: 0.6049 - accuracy: 0.7951 - val_loss: 0.4199 - val_accuracy: 0.8580
# Epoch 6/30
# 600/600 [==============================] - 5s 8ms/step - loss: 0.5914 - accuracy: 0.8003 - val_loss: 0.4391 - val_accuracy: 0.8494
# Epoch 7/30
# 600/600 [==============================] - 5s 8ms/step - loss: 0.5795 - accuracy: 0.8045 - val_loss: 0.4311 - val_accuracy: 0.8548
# Epoch 8/30
# 600/600 [==============================] - 5s 8ms/step - loss: 0.5696 - accuracy: 0.8099 - val_loss: 0.4014 - val_accuracy: 0.8631
# Epoch 9/30
# 600/600 [==============================] - 5s 8ms/step - loss: 0.5662 - accuracy: 0.8127 - val_loss: 0.3931 - val_accuracy: 0.8666
# Epoch 10/30
# 600/600 [==============================] - 5s 8ms/step - loss: 0.5591 - accuracy: 0.8110 - val_loss: 0.4410 - val_accuracy: 0.8444
# Epoch 11/30
# 600/600 [==============================] - 5s 8ms/step - loss: 0.5550 - accuracy: 0.8144 - val_loss: 0.4030 - val_accuracy: 0.8634
# Epoch 12/30
# 600/600 [==============================] - 5s 9ms/step - loss: 0.5491 - accuracy: 0.8170 - val_loss: 0.4197 - val_accuracy: 0.8508
# Epoch 13/30
# 600/600 [==============================] - 5s 9ms/step - loss: 0.5463 - accuracy: 0.8190 - val_loss: 0.4071 - val_accuracy: 0.8640
# Epoch 14/30
# 600/600 [==============================] - 5s 9ms/step - loss: 0.5421 - accuracy: 0.8180 - val_loss: 0.3855 - val_accuracy: 0.8662
# Epoch 15/30
# 600/600 [==============================] - 6s 10ms/step - loss: 0.5280 - accuracy: 0.8241 - val_loss: 0.3994 - val_accuracy: 0.8648
# Epoch 16/30
# 600/600 [==============================] - 6s 9ms/step - loss: 0.5324 - accuracy: 0.8228 - val_loss: 0.4013 - val_accuracy: 0.8657
# Epoch 17/30
# 600/600 [==============================] - 5s 8ms/step - loss: 0.5343 - accuracy: 0.8232 - val_loss: 0.4218 - val_accuracy: 0.8559
# Epoch 18/30
# 600/600 [==============================] - 5s 8ms/step - loss: 0.5290 - accuracy: 0.8248 - val_loss: 0.4064 - val_accuracy: 0.8663
# Epoch 19/30
# 600/600 [==============================] - 5s 8ms/step - loss: 0.5268 - accuracy: 0.8252 - val_loss: 0.4061 - val_accuracy: 0.8692
# Epoch 20/30
# 600/600 [==============================] - 5s 8ms/step - loss: 0.5193 - accuracy: 0.8267 - val_loss: 0.3944 - val_accuracy: 0.8702
# Epoch 21/30
# 600/600 [==============================] - 5s 8ms/step - loss: 0.5193 - accuracy: 0.8276 - val_loss: 0.3990 - val_accuracy: 0.8700
# Epoch 22/30
# 600/600 [==============================] - 5s 8ms/step - loss: 0.5083 - accuracy: 0.8307 - val_loss: 0.4019 - val_accuracy: 0.8672
# Epoch 23/30
# 600/600 [==============================] - 5s 8ms/step - loss: 0.5163 - accuracy: 0.8295 - val_loss: 0.3940 - val_accuracy: 0.8721
# Epoch 24/30
# 600/600 [==============================] - 5s 9ms/step - loss: 0.5096 - accuracy: 0.8289 - val_loss: 0.3912 - val_accuracy: 0.8712
# Epoch 25/30
# 600/600 [==============================] - 5s 8ms/step - loss: 0.5051 - accuracy: 0.8291 - val_loss: 0.4195 - val_accuracy: 0.8620
# Epoch 26/30
# 600/600 [==============================] - 5s 8ms/step - loss: 0.5127 - accuracy: 0.8284 - val_loss: 0.4025 - val_accuracy: 0.8643
# Epoch 27/30
# 600/600 [==============================] - 5s 8ms/step - loss: 0.5130 - accuracy: 0.8289 - val_loss: 0.3896 - val_accuracy: 0.8720
# Epoch 28/30
# 600/600 [==============================] - 5s 9ms/step - loss: 0.5071 - accuracy: 0.8325 - val_loss: 0.4002 - val_accuracy: 0.8691
# Epoch 29/30
# 600/600 [==============================] - 5s 8ms/step - loss: 0.5044 - accuracy: 0.8324 - val_loss: 0.3793 - val_accuracy: 0.8755
# Epoch 30/30
# 600/600 [==============================] - 5s 8ms/step - loss: 0.4983 - accuracy: 0.8349 - val_loss: 0.3834 - val_accuracy: 0.8714

# %%
test_loss_fashion, test_acc_fashion = model.evaluate(X_test_fashion, y_test_fashion)
# Out:
# 313/313 [==============================] - 2s 6ms/step - loss: 0.3834 - accuracy: 0.8714

# %%
print('Fashion MNIST Test accuracy:', round(test_acc_fashion,4))
# Out:
# Fashion MNIST Test accuracy: 0.8714

# %%
#Predicting the labels-Fashion
y_predict_fash = model.predict(X_test_fashion)
y_predict_fash=np.argmax(y_predict_fash, axis=1)
y_test_fash_eval=np.argmax(y_test_fashion, axis=1)
# Out:
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x00000228C05C5B88> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x00000228C05C5B88> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert

# %%
con_mat=confusion_matrix(y_test_fash_eval,y_predict_fash)
plt.style.use('seaborn-deep')
plt.figure(figsize=(10,10))
sns.heatmap(con_mat,annot=True,annot_kws={'size': 15},linewidths=0.5,fmt="d",cmap="gray")
plt.title('True or False predicted Fashion MNIST\n',fontweight='bold',fontsize=15)
plt.show()

# %%
from sklearn.metrics import classification_report

print(classification_report(y_test_fash_eval,y_predict_fash))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.79      0.86      0.83      1000
#            1       0.98      0.98      0.98      1000
#            2       0.81      0.79      0.80      1000
#            3       0.87      0.91      0.89      1000
#            4       0.73      0.87      0.79      1000
#            5       0.98      0.92      0.95      1000
#            6       0.77      0.55      0.64      1000
#            7       0.92      0.92      0.92      1000
#            8       0.98      0.96      0.97      1000
#            9       0.91      0.97      0.94      1000
#
#     accuracy                           0.87     10000
#    macro avg       0.87      0.87      0.87     10000
# weighted avg       0.87      0.87      0.87     10000

# %%
print(history.history.keys())
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
# summarize history for accuracy
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='best')
plt.show()

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='best')
plt.show()

# %%
#tf.expand_dims(X_test_digit[0])
y_predict = model.predict(X_test_fashion.loc[[0],:].values)
y_predict=np.argmax(y_predict, axis=1) # Here we get the index of maximum value in the encoded vector
y_test_digit_eval=np.argmax(y_test_fashion, axis=1)

# %%
#Names of clothing accessories in order 
col_names = ['T-shirt/top','Trouser','Pullover','Dress','Coat','Sandal','Shirt','Sneaker','Bag','Ankle boot']

#Visualizing the images
plt.figure(figsize=(10,10))

plt.imshow(x_train_reshape[0], cmap='gray')
plt.xlabel("Actual:{},Pred:{}".format(col_names[np.argmax(y_test_fashion[0])],col_names[y_predict[0]]))
plt.show()
